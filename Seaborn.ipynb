# %% [markdown]
# # Olimpiyat Datası

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\HP\\OneDrive\\Masaüstü\\Data Science\\Data\\archive\\athlete_events.csv")

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.isnull()
# Out:
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# 271115  False  False  False  False   False   False  False  False  False
#
#          Year  Season   City  Sport  Event  Medal
# 0       False   False  False  False  False   True
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
plt.scatter("Height", "Weight", data = data)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height vs Weight")
plt.show()

# %% [markdown]
# # Searborn

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "Height", y = "Weight", data = data) 
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %%
#cinsiyete göre boy kilo dağılımı 
#hue neyi aydınlatmak istiyorsan o kolonun adını koyabilirsin
sns.set_style("whitegrid")
sns.scatterplot(x = "Height", y = "Weight", data = data, hue = "Sex")
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %% [markdown]
# ### Seaborn Grafik Çeşitleri

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data["Medal"].unique() # kolondaki unique değerleri görebiliyoruz (pandas)
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
data["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
#cinsiyete göre boy kilo dağılımı 
#hue neyi aydınlatmak istiyorsan o kolonun adını koyabilirsin
sns.set_style("whitegrid")
sns.scatterplot(x = "Height", y = "Weight", data = data, hue = "Medal")
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %%
#cinsiyete göre boy kilo dağılımı 
#hue neyi aydınlatmak istiyorsan o kolonun adını koyabilirsin
sns.set_style("whitegrid")
sns.scatterplot(x = "Height", y = "Weight", data = data, hue = "Sex", style = "Medal") 
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %%
#cinsiyete göre boy kilo dağılımı 
#hue neyi aydınlatmak istiyorsan o kolonun adını koyabilirsin
sns.set_style("whitegrid")
sns.scatterplot(x = "Height", y = "Weight", data = data, hue = "Sex", style = "Medal", size = "Age") 
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %%
sns.set_style("whitegrid")
sns.lineplot(x = "Height", y = "Weight", data = data , hue = "Sex")
plt.xlabel("Weight of Atheletes")
plt.ylabel("Weight of Athletes")
plt.show()

# %%
sns.set_style("whitegrid")
sns.displot(x = "Height",hue = "Sex",data = data)
plt.ylabel("Frequency")
plt.title("Athletes Height Histogram")
# Out:
# Text(0.5, 1.0, 'Athletes Height Histogram')

# %%
sns.set_style("whitegrid")
sns.displot(x = "Height",hue = "Sex",data = data, kind = "kde")
plt.ylabel("Frequency")
plt.title("Athletes Height Histogram")
# Out:
# Text(0.5, 1.0, 'Athletes Height Histogram')

# %%
sns.barplot(x = "Medal",y= "Height", hue = "Sex",data = data)
# Out:
# <Axes: xlabel='Medal', ylabel='Height'>

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data["Season"].unique
# Out:
# <bound method Series.unique of 0         Summer
# 1         Summer
# 2         Summer
# 3         Summer
# 4         Winter
#            ...
# 271111    Winter
# 271112    Winter
# 271113    Winter
# 271114    Winter
# 271115    Winter
# Name: Season, Length: 271116, dtype: object>

# %%
sns.catplot(x = "Medal", y = "Height", hue ="Sex",col = "Season",data = data)

# %%
data.corr(numeric_only = True)
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.003631 -0.011141 -0.009176  0.011885
# Age    -0.003631  1.000000  0.138246  0.212069 -0.115137
# Height -0.011141  0.138246  1.000000  0.796213  0.047578
# Weight -0.009176  0.212069  0.796213  1.000000  0.019095
# Year    0.011885 -0.115137  0.047578  0.019095  1.000000

# %%
sns.heatmap(data.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### BoxPlot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#median , quartile, min , max 1.5 IQR, outlier hepsini tek bir grfikte göreceğiz

# %%
data = np.array([5,7,9,20,22,25,30,32,35,37,40,50,55,60,100])

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y = data)
plt.title("Box Plot")
plt.ylabel("Data Value")
# plt.grid(True)
plt.show()

# %%
data = np.array([5,7,9,20,22,25,30,32,35,37,40,50,55,56,56,56,56,57,60])
plt.figure(figsize=(6,5))
sns.boxplot(y = data)
plt.title("Box Plot")
plt.ylabel("Data Value")
# plt.grid(True)
plt.show()

# %%
data = np.array([5,7,9,20,22,25,30,32,35,37,40,50,55,60])
plt.figure(figsize=(6,5))
sns.boxplot(y = data)
plt.title("Box Plot")
plt.ylabel("Data Value")
# plt.grid(True)
plt.show()

# %% [markdown]
# ### Seaborn Kendi Data Setleri

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Masaüstü\\Data Science\\Data\\titanic.csv")

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.figure(figsize=(13,6))
plt.subplot(1,2,1)
sns.boxplot(x = "class",y = "age", data = df)
plt.title("Age by Class")
plt.xlabel("Class")
plt.ylabel("Age")

plt.subplot(1,2,2)
sns.boxplot(x = "class",y = "fare", data = df)
plt.title("Fare by Class")
plt.xlabel("Class")
plt.ylabel("Fare")
plt.tight_layout()
plt.show()
